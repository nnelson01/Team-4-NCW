# %%
import options as opt
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Problem 2**

# %%
spot = 100.0
expiry = 1
rate = 0.08
div = 0.05
vol = 0.3
nper = 252

# %%
def path():
    binompath = opt.binomial_path(spot, expiry, rate, div, vol, nper)
    price = binompath[-1]
    return binompath, price
binompath, price = path()
plt.plot(binompath)
plt.ylabel("Price")
plt.xlabel("Time in Days")
# Out:
# Text(0.5, 0, 'Time in Days')
