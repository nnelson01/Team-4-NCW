# %%
import numpy as np
import options as opt
import matplotlib.pyplot as plt

# %%
#Problem 2
spot = 100
expiry = 1
rate = .08
div = .05
vol = .3
num = 252

# %%
def path():
    binompath = opt.binomial_path(spot, expiry, rate, div, vol, num)
    binompathprice = binompath[-1]
    return binompath, binompathprice
binompath, binompathprice = path()
plt.plot(binompath)
plt.ylabel("Price")
plt.xlabel("# of Days")
# Out:
# Text(0.5, 0, '# of Days')
